# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **L Aparicio**
#
# Data scientist / machine learning engineer

# %% [markdown]
# *I want to become a data scientist and machine learning engineer to help create new solutions for healthcare problems.*

# %% [markdown]
# ### My code below will prompt you to input a number that will be checked to see if it is an odd or even number!

# %%
number = int(input("Type a number "))
if number % 2 == 0:
    print(f"{number} is an even number! ")
else:
    print(f"{number} is an odd number!")

# %% [markdown]
# #### Best programming languages for data science:
# 1. [Python](https://www.python.org/)
# ---
# 2. [R](https://www.r-project.org/)
# ---
# 3. [SQL](https://en.wikipedia.org/wiki/SQL)
